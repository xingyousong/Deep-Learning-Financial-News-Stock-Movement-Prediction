# %%
import re
import urllib2
import csv
import os
import sys

import time
import datetime

import numpy as np
from bs4 import BeautifulSoup


class news_Reuters:
    def __init__(self):
        fin = open('./input/tickerList.csv')

        filterList = set()
        try: # this is used when we restart a task
            fList = open('./input/finished.reuters')
            for l in fList:
                filterList.add(l.strip())
        except: pass

        dateList = self.dateGenerator(1000) # look back on the past X days
        for line in fin: # iterate all possible tickers
            line = line.strip().split(',')
            line = line[:4]
            ticker, name, exchange, MarketCap = line
            if ticker in filterList: continue
            print("%s - %s - %s - %s" % (ticker, name, exchange, MarketCap))
            self.contents(ticker, name, line, dateList, exchange)

    def contents(self, ticker, name, line, dateList, exchange):
        # https://uk.reuters.com/info/disclaimer
        suffix = {'AMEX': '.A', 'NASDAQ': '.O', 'NYSE': '.N'}
        # e.g. http://www.reuters.com/finance/stocks/company-news/BIDU.O?date=09262017
        url = "http://www.reuters.com/finance/stocks/companyNews/" + ticker + suffix[exchange]
        has_Content = 0
        repeat_times = 4
        # check the website to see if that ticker has many news
        # if true, iterate url with date, otherwise stop
        for _ in range(repeat_times): # repeat in case of http failure
            try:
                time.sleep(np.random.poisson(3))
                response = urllib2.urlopen(url)
                data = response.read()
                #print data #NEWLINEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEe
                soup = BeautifulSoup(data, "lxml")
                has_Content = len(soup.find_all("div", {'class': ['topStory', 'feature']}))
                break
            except:
                continue
        
        # spider task for the past
        # if some company has no news even if we don't input date
        #     set this ticker into the lowest priority list
        #
        # else 
        #     if it doesn't have a single news for NN consecutive days, stop iterating dates
        #     set this ticker into the second-lowest priority list
        ticker_failed = open('./input/news_failed_tickers.csv', 'a+')
        if has_Content > 0:
            missing_days = 0
            for timestamp in dateList:
                hasNews = self.repeatDownload(ticker, line, url, timestamp) 
                if hasNews: missing_days = 0 # if get news, reset missing_days as 0
                else: missing_days += 1
                if missing_days > has_Content * 5 + 20: # 2 NEWS: wait 30 days and stop, 10 news, wait 70 days
                    break # no news in X consecutive days, stop crawling
                if missing_days > 0 and missing_days % 20 == 0: # print the process
                    print("%s has no news for %d days, stop this candidate ..." % (ticker, missing_days))
                    ticker_failed.write(ticker + ',' + timestamp + ',' + 'LOW\n')
        else:
            print("%s has no news" % (ticker))
            today = datetime.datetime.today().strftime("%Y%m%d")
            ticker_failed.write(ticker + ',' + today + ',' + 'LOWEST\n')
        ticker_failed.close()

    def repeatDownload(self, ticker, line, url, timestamp): 
        new_time = timestamp[4:] + timestamp[:4] # change 20151231 to 12312015 to match reuters format
        repeat_times = 3 # repeat downloading in case of http error
        for _ in range(repeat_times): 
            try:
                time.sleep(np.random.poisson(3))
                response = urllib2.urlopen(url + "?date=" + new_time)
                data = response.read() 
                #print data #############NEWWLINEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
                soup = BeautifulSoup(data, "lxml")
                hasNews = self.parser(soup, line, ticker, timestamp)
                if hasNews: return 1 # return if we get the news
                break # stop looping if the content is empty (no error)
            except: # repeat if http error appears
                print('Http error')
                continue
        return 0
  
    def parser(self, soup, line, ticker, timestamp):
        content = soup.find_all("div", {'class': ['topStory', 'feature']})# WE NEED THE ENTIRE TEXT! 
        if len(content) == 0: return 0
        fout = open('./input/news_reuters.csv', 'a+')
        for i in range(len(content)):
            title = content[i].h2.get_text().replace(",", " ").replace("\n", " ")
            #print content[i].p
            body = content[i].p.get_text().replace(",", " ").replace("\n", " ")
            #print content[i]
            if i == 0 and len(soup.find_all("div", class_="topStory")) > 0: news_type = 'topStory'
            else: news_type = 'normal'

            print(ticker, timestamp, title, news_type)
            fout.write(','.join([ticker, line[1], timestamp, title, body, news_type]).encode('utf-8') + '\n')
        fout.close()
        return 1
    
    def dateGenerator(self, numdays): # generate N days until now
        base = datetime.datetime.today()
        date_list = [base - datetime.timedelta(days=x) for x in range(0, numdays)]
        for i in range(len(date_list)): date_list[i] = date_list[i].strftime("%Y%m%d")
        return date_list

def main():
    news_Reuters()

if __name__ == "__main__":
    main()
# Out:
# GOOG - Alphabet Inc - NASDAQ - 524979248469.52
# ('GOOG', '20171107', u"Alphabet's Waymo to launch robotaxis with no human in driver's seat ", 'topStory')
# ('GOOG', '20171107', u"UPDATE 1-Alphabet's Waymo to launch robotaxis with no human in driver's seat ", 'normal')
# ('GOOG', '20171107', u'Indonesia to summon messenger  search engine providers over content ', 'normal')
# ('GOOG', '20171107', u'Indonesia to summon messenger  search engine providers over content ', 'normal')
# ('GOOG', '20171102', u'UPDATE 3-AutoNation announces Waymo fleet repair deal  shares jump ', 'normal')
# ('GOOG', '20171102', u'U.S. lawmakers release sample of Russian-bought Facebook ads ', 'normal')
# ('GOOG', '20171031', u'Google ditched autopilot driving feature after test user napped behind wheel ', 'topStory')
# ('GOOG', '20171031', u'Google ditched autopilot driving feature after test user napped behind wheel ', 'normal')
# ('GOOG', '20171027', u"Alphabet's mobile ad revenue surges; shares jump ", 'topStory')
# ('GOOG', '20171027', u"CORRECTED-UPDATE 4-Alphabet's mobile ad revenue surges; shares jump ", 'normal')
# ('GOOG', '20171027', u'No end in sight for tech giant share gains ', 'normal')
# ('GOOG', '20171026', u'BRIEF-Alphabet posts qtrly earnings per share of $9.57 ', 'topStory')
# ('GOOG', '20171026', u'Alphabet revenue rises 24 pct on mobile advertising growth ', 'normal')
# ('GOOG', '20171026', u'Alphabet looks to snowy Michigan to test self-driving cars ', 'normal')
# ('GOOG', '20171026', u'Alphabet looks to snowy Michigan to test self-driving cars ', 'normal')
# ('GOOG', '20171020', u'Alphabet balloon project to provide limited internet in Puerto Rico ', 'topStory')
# ('GOOG', '20171020', u'UPDATE 1-Alphabet balloon project to provide limited internet in Puerto Rico ', 'normal')
# ('GOOG', '20171020', u'Alphabet balloon project to provide limited internet in Puerto Rico ', 'normal')
# ('GOOG', '20171020', u"Alphabet's CapitalG leads Lyft's $1 billion funding round ", 'normal')
# ('GOOG', '20171020', u'PRESS DIGEST-New York Times business news - Oct 20 ', 'normal')
# ('GOOG', '20171019', u"UPDATE 4-Alphabet's CapitalG leads Lyft's $1 bln funding round ", 'topStory')
# ('GOOG', '20171019', u'Lyft says Alphabet leads latest $1 billion round of funding ', 'normal')
# ('GOOG', '20171017', u'Alphabet to develop high-tech waterfront site in Toronto ', 'topStory')
# ('GOOG', '20171017', u'UPDATE 3-Alphabet to develop high-tech waterfront site in Toronto ', 'normal')
# ('GOOG', '20171017', u'Google launches advanced Gmail security features for high-risk users ', 'normal')
# ('GOOG', '20171013', u'Fidelity tests virtual reality for customer service training ', 'normal')
# ('GOOG', '20171009', u'Alphabet launches U.S. ad campaign to promote driverless car safety ', 'topStory')
# ('GOOG', '20171009', u'Alphabet launches U.S. ad campaign to promote driverless car safety ', 'normal')
# ('GOOG', '20171007', u'Google to use balloons to provide Puerto Rico cell service ', 'topStory')
# ('GOOG', '20171007', u'UPDATE 1-Google to use balloons to provide Puerto Rico cell service ', 'normal')
# ('GOOG', '20171005', u'Social media executives to testify Nov. 1 about Russia and U.S. election ', 'topStory')
# ('GOOG', '20171005', u'Social media executives to testify Nov. 1 about Russia and U.S. election ', 'normal')
# ('GOOG', '20171005', u'Google launches new phones  speakers in hardware push ', 'normal')
# ('GOOG', '20171004', u'UPDATE 3-Google launches new phones  speakers in hardware push ', 'topStory')
# ('GOOG', '20171004', u'UPDATE 1-Alphabet unit nears deal for Toronto waterfront development -WSJ ', 'normal')
# ('GOOG', '20171004', u'Alphabet unit nears deal for Toronto waterfront development -WSJ ', 'normal')
# ('GOOG', '20171004', u"BRIEF-Alphabet's Google launches slew of new products headlined by Google Pixel 2 ", 'normal')
# ('GOOG', '20171003', u'UPDATE 1-U.S. judge says he will delay Uber-Waymo trade secrets trial ', 'normal')
# ('GOOG', '20170927', u'U.S. lawmakers ask Facebook  Twitter for information on anti-fracking ads ', 'topStory')
# ('GOOG', '20170922', u'UPDATE 1-Zuckerberg nixes new Facebook share class after shareholder lawsuit ', 'normal')
# ('GOOG', '20170921', u"Google to buy part of HTC's smartphone operations for $1.1 bln ", 'normal')
# ('GOOG', '20170920', u'Waymo seeking $2.6 bln from Uber for one trade secret - lawyer ', 'topStory')
# ('GOOG', '20170920', u'Waymo seeking $2.6 billion from Uber for one trade secret: lawyer ', 'normal')
# ('GOOG', '20170920', u'UPDATE 1-Waymo seeking $2.6 bln from Uber for one trade secret -lawyer ', 'normal')
# ('GOOG', '20170920', u"Google close to buying smartphone maker HTC's assets: Bloomberg ", 'normal')
# ('GOOG', '20170920', u"Google close to buying smartphone maker HTC's assets -Bbg ", 'normal')
# ('GOOG', '20170920', u"Amazon working on 'smart glasses' as its first wearable device: FT ", 'normal')
# ('GOOG', '20170920', u"Amazon working on 'smart glasses' as its first wearable device - FT ", 'normal')
# ('GOOG', '20170915', u'Alphabet talks with Lyft about possible investment: source ', 'topStory')
# ('GOOG', '20170915', u"CORRECTED-GM's Cruise aims to open self-driving tests to public; timing unclear ", 'normal')
# ('GOOG', '20170915', u'Google disables offensive ad keywords found by BuzzFeed ', 'normal')
# ('GOOG', '20170915', u'Alphabet talks with Lyft about possible investment -source ', 'normal')
# ('GOOG', '20170914', u'BRIEF-Alphabet Inc to consider Lyft investment of about $1 bln - Bloomberg ', 'topStory')
# ('GOOG', '20170914', u'Uber  Waymo clash over key evidence in self-driving trial ', 'normal')
# ('GOOG', '20170914', u'Lawsuit accuses Google of discriminating against women in pay  promotions ', 'normal')
# ('GOOG', '20170914', u'Uber  Waymo clash over key evidence in self-driving trial ', 'normal')
# ('GOOG', '20170914', u'Uber  Waymo clash over key evidence in self-driving trial ', 'normal')
# ('GOOG', '20170913', u"Uber's bid to move Waymo court fight to arbitration denied by appeals court ", 'topStory')
# ('GOOG', '20170913', u"Uber's bid to move Waymo court fight to arbitration denied by appeals court ", 'normal')
# ('GOOG', '20170913', u"UPDATE 1-Uber's bid to move Waymo court fight to arbitration denied by appeals court ", 'normal')
# ('GOOG', '20170907', u'Lyft to offer rides in self-driving cars in San Francisco area ', 'normal')
# ('GOOG', '20170829', u"Alphabet's Google acts to comply with EU antitrust order ", 'topStory')
# ('GOOG', '20170829', u"UPDATE 2-Alphabet's Google acts to comply with EU antitrust order ", 'normal')
# ('GOOG', '20170828', u'UPDATE 1-Four Uber drivers fined in Denmark  others charged ', 'normal')
# ('GOOG', '20170825', u"BUZZ-BlackRock's largest mutual fund appears to warm to Google again ", 'topStory')
# ('GOOG', '20170814', u'U.S. hedge funds bearish on FAANG stocks in second-quarter: SEC filings ', 'topStory')
# ('GOOG', '20170814', u'BRIEF-Tiger Global Management cuts stake in Amazon.com  Alphabet ', 'normal')
# ('GOOG', '20170811', u'BRIEF-Third Point ups share stake in Facebook  dissolves in Snap Inc ', 'topStory')
# ('GOOG', '20170811', u'Google cancels staff meeting over fears of online harassment ', 'normal')
# ('GOOG', '20170811', u'UPDATE 1-Google cancels staff meeting over fears of online harassment ', 'normal')
# ('GOOG', '20170811', u'Google cancels staff meeting over fears of online harassment ', 'normal')
# ('GOOG', '20170810', u"UPDATE 2-Uber's Graves stepping down from full-time job  stays on board ", 'normal')
# ('GOOG', '20170808', u'Google fires employee behind anti-diversity memo ', 'topStory')
# ('GOOG', '20170807', u"Omega's Cooperman tells CNBC his biggest position is Alphabet ", 'topStory')
# ('GOOG', '20170807', u"Omega's Cooperman tells CNBC his biggest position is Alphabet ", 'normal')
# ('GOOG', '20170727', u'Google hopes to train 10 million people in Africa in online skills: CEO ', 'topStory')
# ('GOOG', '20170727', u'Facebook shares hit record high as mobile ad sales soar ', 'normal')
# ('GOOG', '20170727', u'UPDATE 4-Facebook shares hit record high as mobile ad sales soar ', 'normal')
# ('GOOG', '20170726', u"BRIEF-Alphabet's Google announces $50 mln initiative to help people prepare for the changing nature of work - Blog ", 'topStory')
# ('GOOG', '20170726', u'One year after IPO  Japanese chat app Line reports drop in user numbers ', 'normal')
# ('GOOG', '20170726', u'UPDATE 2-One year after IPO  Japanese chat app Line reports drop in user numbers ', 'normal')
# ('GOOG', '20170725', u'Google Canada head exits  company names interim head ', 'topStory')
# ('GOOG', '20170725', u'UPDATE 1-Google Canada head exits  company names interim head ', 'normal')
# ('GOOG', '20170725', u'Adobe to pull plug on Flash  ending an era ', 'normal')
# ('GOOG', '20170725', u'ADOBE SYSTEMS WILL END SUPPORT FOR WIDELY USED FLASH MULTIMEDIA SOFTWARE BY 2020 ', 'normal')
# ('GOOG', '20170725', u'Investors unhappy as Alphabet shells out more to drive traffic ', 'normal')
# ('GOOG', '20170725', u"US STOCKS-McDonald's  Caterpillar power S&P to record ", 'normal')
# ('GOOG', '20170725', u'Investors unhappy as Alphabet shells out more to drive traffic ', 'normal')
# ('GOOG', '20170725', u'Alphabet adds to cash pile despite higher costs  antitrust fine ', 'normal')
# ('GOOG', '20170725', u'UPDATE 4-Alphabet adds to cash pile despite higher costs  antitrust fine ', 'normal')
# ('GOOG', '20170724', u'BRIEF-Alphabet reports qtrly earnings per share of $5.01 ', 'topStory')
# ('GOOG', '20170724', u'BRIEF-Alphabet says Q2 aggregate paid clicks were up 52 pct ', 'normal')
# ('GOOG', '20170724', u'Alphabet profit slumps on record $2.7 bln EU fine ', 'normal')
# ('GOOG', '20170724', u'BRIEF-Alphabet Inc Q2 results press release ', 'normal')
# ('GOOG', '20170724', u'BRIEF-Alphabet appoints Sundar Pichai to its board ', 'normal')
# ('GOOG', '20170724', u'Alphabet appoints Google CEO Pichai to board ', 'normal')
# ('GOOG', '20170724', u'Alphabet appoints Google CEO Pichai to board ', 'normal')
# ('GOOG', '20170719', u"Google redesigns mobile search app with personalized 'feed' ", 'topStory')
# ('GOOG', '20170712', u'Google Earth to let users post stories  photos in coming years ', 'topStory')
# ('GOOG', '20170712', u'China could field nearly half of new electric car models by 2020 - study ', 'normal')
# ('GOOG', '20170707', u'Waymo must disclose details of Lyft car deal to Uber -ruling ', 'topStory')
# ('GOOG', '20170707', u'Facebook to build housing in Silicon Valley for first time ', 'normal')
# ('GOOG', '20170707', u'Waymo must disclose details of Lyft car deal to Uber: ruling ', 'normal')
# ('GOOG', '20170707', u'Waymo must disclose details of Lyft car deal to Uber -ruling ', 'normal')
# ('GOOG', '20170707', u'Google says its service disruption issue resolved ', 'normal')
# ('GOOG', '20170707', u'Google says its Drive service facing disruption ', 'normal')
# ('GOOG', '20170706', u'Alphabet spins out geothermal startup Dandelion ', 'topStory')
# ('GOOG', '20170706', u'Alphabet spins out geothermal startup Dandelion ', 'normal')
# ('GOOG', '20170705', u"China's Baidu taps 50 partners to help advance self-driving ", 'topStory')
# ('GOOG', '20170705', u"China's Baidu taps 50 partners to help advance self-driving ", 'normal')
# ('GOOG', '20170705', u'Google to start getting Norwegian wind power by September ', 'normal')
# ('GOOG', '20170628', u'In EU dealings  Google could learn from an erstwhile rival ', 'normal')
# ('GOOG', '20170628', u'Google faces years of EU oversight on top of record antitrust fine ', 'normal')
# ('GOOG', '20170628', u'REFILE-Google faces years of EU oversight on top of record antitrust fine ', 'normal')
# ('GOOG', '20170627', u'BRIEF-Alphabet expects to accrue fine imposed by EC decision in Q2\u200d\u200b ', 'topStory')
# ('GOOG', '20170627', u'EU hits Google with record $2.7 bln fine ', 'normal')
# ('GOOG', '20170627', u'EU fines Google record $2.7 billion in first antitrust case ', 'normal')
# ('GOOG', '20170627', u'Google says it is considering appeal against EU antitrust fine ', 'normal')
# ('GOOG', '20170627', u'EU antitrust regulators hit Google with record 2.42 bln euro fine ', 'normal')
# ('GOOG', '20170626', u'Alphabet partners with Avis to manage self-driving car fleet ', 'topStory')
# ('GOOG', '20170623', u'Google to stop scanning Gmail for creating targeted ads ', 'topStory')
# ('GOOG', '20170623', u'Google to stop scanning Gmail for creating targeted ads ', 'normal')
# ('GOOG', '20170623', u'London startup Blockchain raises $40 million in fresh funding ', 'normal')
# ('GOOG', '20170622', u'Uber CEO Travis Kalanick resigns under investor pressure ', 'normal')
# ('GOOG', '20170622', u'UPDATE 9-Uber CEO Travis Kalanick resigns under investor pressure ', 'normal')
# ('GOOG', '20170619', u'Google tightens measures to remove extremist content on YouTube ', 'topStory')
# ('GOOG', '20170619', u'Google tightens measures to remove extremist content on YouTube ', 'normal')
# ('GOOG', '20170615', u'Alphabet  Apple analyst research extends tech stock selloff ', 'topStory')
# ('GOOG', '20170613', u'Waymo retires Firefly to focus on mass-produced vehicles ', 'topStory')
# ('GOOG', '20170613', u'Indonesia has reached tax deal with Google for 2016  finance minister  says ', 'normal')
# ('GOOG', '20170613', u'Indonesia has reached tax deal with Google for 2016 -finmin ', 'normal')
# ('GOOG', '20170609', u'SoftBank to buy robotics businesses from Alphabet Inc ', 'topStory')
# ('GOOG', '20170609', u'UPDATE 3-SoftBank to buy robotics businesses from Alphabet Inc ', 'normal')
# ('GOOG', '20170609', u'SoftBank unit agrees to buy Boston Dynamics from Alphabet Inc ', 'normal')
# ('GOOG', '20170609', u'BRIEF-SoftBank announces agreement to acquire Boston Dynamics ', 'normal')
# ('GOOG', '20170607', u'Judge rules Uber must disclose key document in Waymo self-driving car case ', 'topStory')
# ('GOOG', '20170607', u'Judge rules Uber must disclose key document in Waymo self-driving car case ', 'normal')
# ('GOOG', '20170607', u'Judge rules Uber must disclose key document in Waymo self-driving car case ', 'normal')
# ('GOOG', '20170607', u"UPDATE 1-Lack of power lines hits sub-Saharan Africa's biggest wind farm ", 'normal')
# ('GOOG', '20170602', u"BRIEF-Alphabet Inc's \u200dnest Labs and Ecobee announce long-term patent cross-license agreement\u200b ", 'topStory')
# ('GOOG', '20170602', u'Waymo working on self-driving trucks ', 'normal')
# ('GOOG', '20170602', u'Waymo working on self-driving trucks ', 'normal')
# ('GOOG', '20170601', u'Exclusive: Google faces hefty EU fine in shopping case by August - sources ', 'topStory')
# ('GOOG', '20170531', u'Uber fires self-driving car chief at center of court case ', 'normal')
# ('GOOG', '20170530', u'Uber fires Levandowski amid Waymo self-driving dispute ', 'topStory')
# ('GOOG', '20170526', u'Acquisitions accelerate as tech giants seek to build AI smarts ', 'normal')
# ('GOOG', '20170522', u'EU to conclude Google antitrust cases in next few months ', 'topStory')
# ('GOOG', '20170522', u'EU to conclude Google antitrust cases in next few months ', 'normal')
# ('GOOG', '20170522', u'EU to conclude Google antitrust cases in next few months ', 'normal')
# ('GOOG', '20170518', u'Google shifts mobile focus to apps and digital assistant ', 'topStory')
# ('GOOG', '20170517', u'UPDATE 3-Google shifts mobile focus to apps and digital assistant ', 'topStory')
# ('GOOG', '20170516', u'Wall St chat service Symphony raises $63 mln; valued at $1 bln-source ', 'normal')
# ('GOOG', '20170515', u'BRIEF-Paulson & Co Inc takes share stake in Dish Network  Monsanto ', 'topStory')
# ('GOOG', '20170515', u'BRIEF-Omega Advisors ups share stake in Alphabet  Facebook  Zynga  Time Inc ', 'normal')
# ('GOOG', '20170512', u'BRIEF-Third Point cuts share stake in Facebook  JPMorgan  ups in Alphabet ', 'topStory')
# ('GOOG', '20170504', u'Google to pay $334 million to settle Italian tax dispute ', 'topStory')
# ('GOOG', '20170504', u'UPDATE 1-Google to pay 306 mln euros to settle Italian tax dispute ', 'normal')
# ('GOOG', '20170504', u'Spam campaign targets Google users with malicious link ', 'normal')
# ('GOOG', '20170503', u'UPDATE 3-Spam campaign targets Google users with malicious link ', 'topStory')
# ('GOOG', '20170503', u"Investors cheer Delphi's bet on electric  connected cars ", 'normal')
# ('GOOG', '20170503', u"UPDATE 6-Investors cheer Delphi's bet on electric  connected cars ", 'normal')
# ('GOOG', '20170503', u'Google Docs warns customers about spam with malicious links ', 'normal')
# ('GOOG', '20170503', u'Italy expects to settle Google tax dispute this week - sources ', 'normal')
# ('GOOG', '20170503', u'Italy expects to settle Google tax dispute this week - sources ', 'normal')
# ('GOOG', '20170503', u'Italy tax chief says close to deal with Google over tax dispute: paper ', 'normal')
# ('GOOG', '20170503', u'Italy tax chief says close to deal with Google over tax dispute-paper ', 'normal')
# ('GOOG', '20170429', u'Google gets Australian tax office demand to pay more  says to fight it ', 'topStory')
# ('GOOG', '20170429', u'Google gets Australian tax office demand to pay more  says to fight it ', 'normal')
# ('GOOG', '20170428', u"BRIEF-Alphabet's Google CEO Sundar Pichai's 2016 total compensation $199.7 mln ", 'topStory')
# ('GOOG', '20170428', u'Big-data analytics company Cloudera surges in market debut ', 'normal')
# ('GOOG', '20170428', u"Google's search for non-ad revenue puts spotlight on cloud  Pixel ", 'normal')
# ('GOOG', '20170428', u"UPDATE 1-Google's search for non-ad revenue puts spotlight on cloud  Pixel ", 'normal')
# ('GOOG', '20170428', u"Google's search for non-ad revenue puts spotlight on cloud  Pixel ", 'normal')
# ('GOOG', '20170428', u'Morning News Call - India  April 28 ', 'normal')
# ('GOOG', '20170427', u"Google parent Alphabet's profit up 29 percent on strong ad sales ", 'topStory')
# ('GOOG', '20170427', u"UPDATE 5-Google parent Alphabet's profit up 29 pct on strong ad sales ", 'normal')
# ('GOOG', '20170427', u'US STOCKS-Earnings lift Nasdaq to record; Amazon  Alphabet up after hours ', 'normal')
# ('GOOG', '20170427', u'BRIEF-Alphabet posts qtrly EPS of $7.73 ', 'normal')
# ('GOOG', '20170427', u'BRIEF-Alphabet Inc Q1 results press release ', 'normal')
# ('GOOG', '20170427', u'Alphabet CEO touts results of corporate restructuring ', 'normal')
# ('GOOG', '20170427', u'UPDATE 2-Alphabet CEO touts results of corporate restructuring ', 'normal')
# ('GOOG', '20170425', u'Waymo testing self-driving car ride service in Arizona ', 'topStory')
# ('GOOG', '20170425', u'Waymo testing self-driving car ride service in Arizona ', 'normal')
# ('GOOG', '20170419', u"Alphabet's Verily unit launches study to track health data ", 'topStory')
# ('GOOG', '20170419', u"Alphabet's Verily unit launches study to track health data ", 'normal')
# ('GOOG', '20170417', u'Google to open up Android to rivals in out-of-court deal with Russia ', 'topStory')
# ('GOOG', '20170417', u'Google to open up Android to rivals in out-of-court deal with Russia ', 'normal')
# ('GOOG', '20170417', u'UPDATE 2-Google to open up Android to rivals in out-of-court deal with Russia ', 'normal')
# ('GOOG', '20170413', u"RPT-Self-driving 'arms race' complicates supplier alliances ", 'normal')
# ('GOOG', '20170413', u"Uber CEO's iron grip poses challenge in COO search ", 'normal')
# ('GOOG', '20170413', u"Self-driving 'arms race' complicates supplier alliances ", 'normal')
# ('GOOG', '20170413', u"Self-driving 'arms race' complicates supplier alliances ", 'normal')
# ('GOOG', '20170410', u'RPT-In the Trump era  one U.S. Muslim investor tries a louder voice ', 'normal')
# ('GOOG', '20170410', u'In the Trump era  one U.S. Muslim investor tries a louder voice ', 'normal')
# ('GOOG', '20170407', u"Uber says its self-driving technology differs from Waymo's ", 'topStory')
# ('GOOG', '20170407', u'YouTube tweaks ad strategy to curb content stealing ', 'normal')
# ('GOOG', '20170407', u"Uber says its self-driving technology differs from Waymo's ", 'normal')
# ('GOOG', '20170407', u"UPDATE 2-Uber says its self-driving technology differs from Waymo's ", 'normal')
# ('GOOG', '20170406', u'YouTube tweaks ad strategy to curb content stealing ', 'topStory')
# ('GOOG', '20170406', u'U.S. judge warns Uber in Waymo self-driving car case ', 'normal')
# ('GOOG', '20170405', u'U.S. judge warns Uber in Waymo self-driving car case ', 'topStory')
# ('GOOG', '20170404', u"Uber exec has 'no basis' to believe criminal probe underway -court filing ", 'topStory')
# ('GOOG', '20170404', u"Uber executive has 'no basis' to believe criminal probe underway: court filing ", 'normal')
# ('GOOG', '20170404', u"UPDATE 1-Uber exec has 'no basis' to believe criminal probe underway -court filing ", 'normal')
# ('GOOG', '20170327', u"Facebook's Messenger app adds live location-sharing ", 'topStory')
# ('GOOG', '20170327', u"Facebook's Messenger app adds live location-sharing ", 'normal')
# ('GOOG', '20170327', u"UPDATE 1-Facebook's Messenger app adds live location-sharing ", 'normal')
# ('GOOG', '20170327', u"Facebook's Messenger app to allow live location-sharing ", 'normal')
# ('GOOG', '20170324', u'BRIEF-Moody\'s says Alphabet\'s loss of "notable advertisers" on YouTube platform credit negative  but does not impact AA2 rating ', 'topStory')
# ('GOOG', '20170324', u"RPT-YouTube's bid to grab TV dollars imperiled by advertiser revolt ", 'normal')
# ('GOOG', '20170324', u"YouTube's bid to grab TV dollars imperiled by advertiser revolt ", 'normal')
# ('GOOG', '20170324', u"YouTube's bid to grab TV dollars imperiled by advertiser revolt ", 'normal')
# ('GOOG', '20170322', u'Google allows users to share their locations in mapping app ', 'topStory')
# ('GOOG', '20170322', u'Google allows users to share their locations in mapping app ', 'normal')
# ('GOOG', '20170322', u'Google allows users to share their locations in mapping app ', 'normal')
# ('GOOG', '20170317', u'EU consumer authorities to take on Facebook  Google  Twitter ', 'topStory')
# ('GOOG', '20170317', u"U.S. financial firms embrace cloud  'fat fingers' notwithstanding ", 'normal')
# ('GOOG', '20170315', u'Turner  Fox  Viacom to offer advertisers way to laser focus on audience ', 'normal')
# ('GOOG', '20170311', u'Alphabet adds patent claim to Uber intellectual property theft lawsuit ', 'topStory')
# ('GOOG', '20170311', u'UPDATE 2-Alphabet adds patent claim to Uber intellectual property theft lawsuit ', 'normal')
# ('GOOG', '20170310', u'Alphabet adds patent claim to Uber intellectual property theft lawsuit ', 'topStory')
# ('GOOG', '20170310', u'Alphabet self-driving car unit seeks injunction against Uber ', 'normal')
# ('GOOG', '20170307', u'Google reported by Danish watchdog for unlimited data storage ', 'topStory')
# ('GOOG', '20170307', u'Google reported by Danish watchdog for unlimited data storage ', 'normal')
# ('GOOG', '20170307', u'Google foe takes Android complaint to regulators ', 'normal')
# ('GOOG', '20170306', u'RPT-Alphabet lawsuit against Uber cements end of uneasy marriage ', 'topStory')
# ('GOOG', '20170306', u'Alphabet lawsuit against Uber cements end of uneasy marriage ', 'normal')
# ('GOOG', '20170306', u'Alphabet lawsuit against Uber cements end of uneasy marriage ', 'normal')
# ('GOOG', '20170301', u"Uber's self-driving unit quietly bought firm with tech at heart of Alphabet lawsuit ", 'topStory')
# ('GOOG', '20170301', u"RPT-Uber's self-driving unit quietly bought firm with tech at heart of Alphabet lawsuit ", 'normal')
# ('GOOG', '20170301', u"Uber's self-driving unit quietly bought firm with tech at heart of Alphabet lawsuit ", 'normal')
# ('GOOG', '20170228', u'CORRECTED-Uber exec asked to resign for not disclosing prior sexual harassment allegation- Recode ', 'topStory')
# ('GOOG', '20170225', u"Alphabet's self-driving car unit sues Uber with trade theft charge ", 'topStory')
# ('GOOG', '20170224', u"Alphabet's self-driving car unit sues Uber with trade theft charge ", 'topStory')
# ('GOOG', '20170224', u"Alphabet's self-driving car unit sues Uber with trade theft charge ", 'normal')
# ('GOOG', '20170224', u"UPDATE 2-Alphabet's self-driving car unit sues Uber with trade theft charge ", 'normal')
# ('GOOG', '20170222', u"BRIEF-S&P upgrades Alphabet Inc to 'AA+' on continued strong operating performance  conservative financial policy ", 'topStory')
# ('GOOG', '20170222', u'Confident Snap brushes off concerns on second day of IPO roadshow ', 'normal')
# ('GOOG', '20170217', u"BlackRock's largest mutual fund sours on Google ", 'normal')
# ('GOOG', '20170216', u"Telenor to roll out Google's new messaging service in Asia  Europe ", 'topStory')
# ('GOOG', '20170216', u"UPDATE 1-Telenor to roll out Google's new messaging service in Asia  Europe ", 'normal')
# ('GOOG', '20170216', u"Telenor to roll out Google's new messaging service in Asia  Europe ", 'normal')
# ('GOOG', '20170214', u'BRIEF-Jana Partners LLC dissolves sole share stake in Alphabet  Marathon Petroleum ', 'topStory')
# ('GOOG', '20170214', u'BRIEF-Omega Advisors cuts share stake in Alphabet  Microsoft; dissolves in Chesapeake Energy ', 'normal')
# ('GOOG', '20170210', u'BRIEF-Vanguard Group reports 6.49 pct passive stake in Alphabet Inc as of Dec. 31 ', 'topStory')
# ('GOOG', '20170203', u"UPDATE 5-Uber CEO quits Trump's business advisory group ", 'normal')
# ('GOOG', '20170202', u'UPDATE 2-Microsoft asks for exception program on Trump immigration orders ', 'normal')
# ('GOOG', '20170202', u'Microsoft asks Trump administration for exception program on immigration orders ', 'normal')
# ('GOOG', '20170127', u"Alphabet's hardware growth adds to strength in core ad business ", 'topStory')
# ('GOOG', '20170127', u'Alphabet posts strong revenue growth  higher taxes hit earnings ', 'normal')
# ('GOOG', '20170126', u'BRIEF-Alphabet Inc reports 4th-qtr non-GAAP EPS of $9.36 ', 'topStory')
# ('GOOG', '20170126', u'Alphabet quarterly revenue rises 22.2 pct ', 'normal')
# ('GOOG', '20170126', u'BRIEF-Alphabet Inc quarterly results press release ', 'normal')
# ('GOOG', '20170110', u'RPT-UPDATE 1-Italy looking at Google proposal to settle tax dispute - source ', 'topStory')
# ('GOOG', '20170104', u'U.S. Labor department sues Google for compensation data ', 'topStory')
# GOOG has no news for 20 days, stop this candidate ...
# GOOG has no news for 40 days, stop this candidate ...
# ('GOOG', '20161116', u'Google CEO to meet with EU antitrust chief on Friday ', 'topStory')
# ('GOOG', '20161116', u'Google CEO to meet with EU antitrust chief on Friday ', 'normal')
# ('GOOG', '20161115', u'Google announces artificial intelligence group for Google Cloud ', 'topStory')
# ('GOOG', '20161115', u'Google says it will expand operations in London ', 'normal')
# ('GOOG', '20161115', u'Apple considering expansion into wearable glasses - Bloomberg ', 'normal')
# ('GOOG', '20161114', u'BRIEF-Soros Fund Management takes share stake in Alphabet  dissolves stake in GM - SEC filing ', 'topStory')
# ('GOOG', '20161114', u'BRIEF-Appaloosa cuts share stake in Alphabet  ups in Kinder Morgan ', 'normal')
# ('GOOG', '20161114', u'BRIEF-Tiger Global Management raises share stake in Apple  cuts share stake in Amazon ', 'normal')
# ('GOOG', '20161114', u'BRIEF-Jana Partners cuts sole share stake in Alphabet  takes sole share stake in Mondelez International ', 'normal')
# ('GOOG', '20161110', u'BRIEF-Third Point ups stake in Alphabet & Facebook  cuts in Charter ', 'topStory')
# ('GOOG', '20161107', u'Eye-tracking firm Tobii to raise cash for virtual reality  smartphone investments ', 'normal')
# ('GOOG', '20161105', u"Alphabet's unit discloses Snapchat investment ", 'normal')
# ('GOOG', '20161103', u'Google formally rejects EU antitrust charges ', 'topStory')
# ('GOOG', '20161027', u"Alphabet's quarterly revenue rises 20.2 percent ", 'topStory')
# ('GOOG', '20161027', u'Indonesia hopes to reach tax settlement with Google: finmin ', 'normal')
# ('GOOG', '20161027', u'Indonesia hopes to reach tax settlement with Google - finmin ', 'normal')
# ('GOOG', '20161026', u'UPDATE 1-Salesforce.com CEO speaks of failed efforts to buy Twitter  LinkedIn ', 'normal')
# ('GOOG', '20161026', u'Salesforce.com CEO speaks of failed efforts to buy Twitter  LinkedIn ', 'normal')
# ('GOOG', '20161020', u'Investment banks scramble to fill top jobs in Italy ', 'normal')
# ('GOOG', '20161020', u'Google signs CBS  in talks with others on web TV: sources ', 'normal')
# ('GOOG', '20161020', u'UPDATE 3-Google signs CBS  in talks with others on web TV -sources ', 'normal')
# ('GOOG', '20161011', u'Google buys digital marketing company FameBit ', 'topStory')
# ('GOOG', '20161011', u'Google buys digital marketing company FameBit ', 'normal')
# ('GOOG', '20161011', u"BRIEF-Alphabet's Google acquires FameBit platform - company blog post ", 'normal')
# ('GOOG', '20161010', u'Salesforce still mulls bid for Twitter as shareholders resist -sources ', 'normal')
# ('GOOG', '20161010', u"Twitter's shares slump on report that potential bidders lose interest ", 'normal')
# ('GOOG', '20161006', u'UPDATE 3-Twitter shares plunge on report bidders are scarce ', 'normal')
# ('GOOG', '20161006', u"Twitter drops 9 percent after report that Google won't bid ", 'normal')
# ('GOOG', '20161006', u"Twitter drops 9 percent after report that Google won't bid ", 'normal')
# ('GOOG', '20160928', u"BRIEF-Alphabet's YouTube hires former Warner Music executive Lyor Cohen as global head of music ", 'topStory')
# ('GOOG', '20160927', u'Google France boss says looking for insurance partners ', 'topStory')
# ('GOOG', '20160927', u'Google launches service to take internet to India malls  cafes ', 'normal')
# ('GOOG', '20160927', u'Google launches service to take internet to India malls  cafes ', 'normal')
# ('GOOG', '20160926', u'Exclusive: Thailand considering tougher tax collection rules for internet  tech firms ', 'normal')
# ('GOOG', '20160915', u'Japan government advisory panel says Apple  Google hinder app competition ', 'topStory')
# ('GOOG', '20160914', u'Japan report shows Apple  Google hinder app competition - Nikkei ', 'topStory')
# ('GOOG', '20160912', u'Sanofi and Alphabet set up JV in diabetes ', 'topStory')
# ('GOOG', '20160908', u'Google given more time to reply to EU antitrust charge on Android ', 'topStory')
# ('GOOG', '20160908', u'CORRECTED-UPDATE 2-Google to buy cloud software company Apigee for $625 mln ', 'normal')
# ('GOOG', '20160908', u'UPDATE 1-Google to buy software developer Apigee in $625 mln deal ', 'normal')
# ('GOOG', '20160908', u'Google to buy software developer Apigee in $625 mln deal ', 'normal')
# ('GOOG', '20160902', u'Exclusive: Google shelves plan for phone with interchangeable parts - sources ', 'topStory')
# ('GOOG', '20160830', u"Google's cloud close to winning PayPal business - CNBC ", 'topStory')
# ('GOOG', '20160822', u"BRIEF-Alphabet - Google CEO Sundar Pichai reports open market sale of Co's class A common stock and class C capital stock ", 'topStory')
# ('GOOG', '20160822', u'Chinese investors buy ad tech startup Media.net for $900 million ', 'normal')
# ('GOOG', '20160822', u'UPDATE 1-Chinese investors buy ad tech startup Media.net for $900 mln ', 'normal')
# ('GOOG', '20160817', u"UPDATE 2-BlackRock's largest mutual fund warns on U.S.  ups Japan stake ", 'normal')
# ('GOOG', '20160811', u'Google Ventures CEO Bill Maris quits - Recode ', 'topStory')
# ('GOOG', '20160811', u'UPDATE 1-Google Ventures CEO Bill Maris quits ', 'normal')
# ('GOOG', '20160802', u"BRIEF-S&P - Alphabet Inc.'s proposed senior unsecured notes are assigned 'AA' issue rating ", 'topStory')
# ('GOOG', '20160802', u"BRIEF-Moody's assigns AA2 rating to Alphabet Inc's new senior unsecured notes ", 'normal')
# ('GOOG', '20160801', u'UPDATE 2-GSK and Google parent forge $715 mln bioelectronic medicines firm ', 'topStory')
# ('GOOG', '20160729', u'Alphabet and Amazon wind up stellar quarter for big tech ', 'topStory')
# ('GOOG', '20160728', u'BRIEF-Alphabet Inc reports Q2 GAAP EPS for Class A and B common stock $7 ', 'topStory')
# ('GOOG', '20160728', u'Google-parent Alphabet revenue up 21.3 percent ', 'normal')
# ('GOOG', '20160722', u'REFILE-UPDATE 3-Verizon emerges as front-runner in Yahoo auction -sources ', 'normal')
# ('GOOG', '20160720', u'Uber driver tells UK tribunal he earned less than the minimum wage ', 'normal')
# ('GOOG', '20160720', u'Uber driver tells UK tribunal he earned less than the minimum wage ', 'normal')
# ('GOOG', '20160714', u'Google says will respond to EU antitrust cases in coming weeks ', 'topStory')
# ('GOOG', '20160712', u'Google notifies users of 4 000 state-sponsored cyber attacks per month: executive ', 'topStory')
# ('GOOG', '20160711', u'Google notifies users of 4 000 state-sponsored cyber attacks per month - exec ', 'topStory')
# ('GOOG', '20160629', u'BRIEF-Alphabet Inc appoints Roger Ferguson member of board ', 'topStory')
# ('GOOG', '20160620', u'Toyota to build artificial intelligence-based driving systems in 5 years ', 'normal')
# ('GOOG', '20160613', u'Apple expected to showcase new powers for Siri at developer event ', 'normal')
# ('GOOG', '20160609', u'U.S. Congress scrutinizes pay TV billing  competitive practices ', 'normal')
# ('GOOG', '20160609', u'UPDATE 1-U.S. Congress scrutinizes pay TV billing  competitive practices ', 'normal')
# ('GOOG', '20160609', u'Congress scrutinizes pay TV billing  competitive practices ', 'normal')
# ('GOOG', '20160607', u'GM CEO says keep steering wheels  brakes in self-driving cars ', 'normal')
# ('GOOG', '20160603', u"UPDATE 2-CEO of Alphabet Inc's Nest unit steps down ", 'topStory')
# ('GOOG', '20160603', u"Alphabet Inc unit Nest's CEO to step down ", 'normal')
# ('GOOG', '20160603', u'Tiger Global climbs in May  other funds post gains as well ', 'normal')
# ('GOOG', '20160603', u'UPDATE 2-Tiger Global climbs in May  other funds post gains as well ', 'normal')
# ('GOOG', '20160601', u'Toyota in talks to buy robotics divisions from Alphabet: Nikkei ', 'topStory')
# ('GOOG', '20160601', u'Toyota in talks to buy robotics divisions from Alphabet -Nikkei ', 'normal')
# ('GOOG', '20160531', u'Russian watchdog again puts off decision on Google fine ', 'topStory')
# ('GOOG', '20160531', u'Russian watchdog again puts off decision on Google fine ', 'normal')
# ('GOOG', '20160527', u"BRIEF-Moody's says Alphabet's victory in code copyright case is credit positive ", 'topStory')
# ('GOOG', '20160526', u'REFILE-UPDATE 2-Microsoft  Facebook to build transatlantic subsea cable ', 'normal')
# ('GOOG', '20160525', u'For some U.S. companies  millennials are giving way to Generation Z ', 'normal')
# ('GOOG', '20160524', u'UPDATE 3-Investigators raid Google Paris HQ in tax evasion inquiry ', 'normal')
# ('GOOG', '20160519', u'Google doubles down on artificial intelligence with Home and Allo ', 'topStory')
# ('GOOG', '20160518', u"Google unveils Google Home  looks to compete with Amazon's Echo ", 'topStory')
# ('GOOG', '20160518', u'PRESS DIGEST- New York Times business news - May 18 ', 'normal')
# ('GOOG', '20160513', u"Dan Loeb's Third Point adds 700 000 shares of Alphabet: filing ", 'topStory')
# ('GOOG', '20160513', u'BRIEF-Third Point LLC takes share stake in Alphabet Inc - SEC Filing ', 'normal')
# ('GOOG', '20160511', u'FTC taking second look at Google search: Politico ', 'topStory')
# ('GOOG', '20160511', u'FTC taking second look at Google search - Politico ', 'normal')
# ('GOOG', '20160505', u'Digital farming could spell shake-up for crop chemicals sector ', 'normal')
# ('GOOG', '20160503', u'BRIEF-Alphabet says Canadian Competition Bureau closed antitrust probe ', 'topStory')
# ('GOOG', '20160428', u'Fiat Chrysler  Alphabet in technology partnership talks: WSJ ', 'topStory')
# ('GOOG', '20160428', u'REFILE-UPDATE 4-Facebook revenue smashes expectations as mobile ad sales surge ', 'normal')
# ('GOOG', '20160427', u"UPDATE 4-Apple's 9-year iPhone juggernaut stops with first sales decline ", 'normal')
# ('GOOG', '20160426', u"BRIEF-S&P rates Alphabet's Senior unsecured notes 'AA' issue-level rating ", 'topStory')
# ('GOOG', '20160426', u'Google  Ford  Uber launch coalition to further self-driving cars ', 'normal')
# ('GOOG', '20160426', u'BRIEF-Alphabet announces 84 pct final participation in exchange offers ', 'normal')
# ('GOOG', '20160422', u"BRIEF-Moody's comments on EU's antitrust charges against Alphabet ", 'topStory')
# ('GOOG', '20160422', u'US STOCKS-Wall Street ends flat; Alphabet and Microsoft tumble ', 'normal')
# ('GOOG', '20160422', u'US STOCKS-Wall Street mixed as Alphabet  Microsoft tumble ', 'normal')
# ('GOOG', '20160422', u'Microsoft  Google agree to drop complaints against each other ', 'normal')
# ('GOOG', '20160422', u'Microsoft  Google agree to drop complaints against each other ', 'normal')
# ('GOOG', '20160422', u'Microsoft  Google agree to drop complaints against each other ', 'normal')
# ('GOOG', '20160421', u"CORRECTED-UPDATE 2-Google's parent Alphabet misses Wall Street view ", 'topStory')
# ('GOOG', '20160421', u'BRIEF-Alphabet reports 1st-qtr adj earnings of $7.50/shr ', 'normal')
# ('GOOG', '20160421', u"Alphabet's quarterly revenue rises 17.4 pct ", 'normal')
# ('GOOG', '20160419', u'Timeline: Google wins some  loses some in global antitrust battles ', 'normal')
# ('GOOG', '20160419', u'TIMELINE-Google wins some  loses some in global antitrust battles ', 'normal')
# ('GOOG', '20160415', u'Obama urges agency to open competition in cable TV boxes ', 'normal')
# ('GOOG', '20160408', u'Adobe issues emergency update to Flash after ransomware attacks ', 'normal')
# ('GOOG', '20160407', u'UPDATE 2-Verizon plans bid for Yahoo and its Yahoo Japan stake -Bloomberg ', 'normal')
# ('GOOG', '20160407', u'Deals of the day- Mergers and acquisitions ', 'normal')
# ('GOOG', '20160407', u'Verizon plans bid for Yahoo  Google weighs offer - Bloomberg ', 'normal')
# ('GOOG', '20160329', u'Alphabet introduces home phone service ', 'topStory')
# ('GOOG', '20160329', u'Alphabet introduces home phone service ', 'normal')
# ('GOOG', '20160318', u'UPDATE 2-U.S. FCC says it receives 104 bids to participate in spectrum auction ', 'normal')
# ('GOOG', '20160317', u'Alphabet puts robot-maker Boston Dynamics up for sale-Bloomberg ', 'topStory')
# ('GOOG', '20160317', u"Apple signs up for Google's cloud services: Re/code ", 'normal')
# ('GOOG', '20160317', u"Apple signs up for Google's cloud services - Re/code ", 'normal')
# ('GOOG', '20160315', u'Amazon being probed for alleged tax evasion in Italy-Bloomberg ', 'normal')
# ('GOOG', '20160314', u'Google to urge Congress to help get self-driving cars on roads ', 'topStory')
# ('GOOG', '20160310', u'U.S. auto safety agency seeking details of Google self-driving crash ', 'topStory')
# ('GOOG', '20160307', u"Alphabet's Project Fi exiting invite-only mode ", 'topStory')
# ('GOOG', '20160304', u'UK lawmakers say Facebook may have broken tax rules ', 'normal')
# ('GOOG', '20160304', u"More jobs  higher prices: restaurants show U.S. economy's bite ", 'normal')
# ('GOOG', '20160304', u'UPDATE 2-UK lawmakers say Facebook may have broken tax rules ', 'normal')
# ('GOOG', '20160303', u"Google Fiber's video subscriber growth surges 79 percent in 2015 ", 'topStory')
# ('GOOG', '20160219', u"Google accounts show 11 bln euros moved via low tax 'Dutch sandwich' in 2014 ", 'normal')
# ('GOOG', '20160212', u'Google says will not participate in 2016 U.S. airwaves auction ', 'topStory')
# ('GOOG', '20160211', u'UK lawmakers tell Google to come clean on tax ', 'topStory')
# ('GOOG', '20160211', u'Italy opens tax probe on Google managers: sources ', 'normal')
# ('GOOG', '20160211', u'UPDATE 1-Italy opens tax probe on Google managers-sources ', 'normal')
# ('GOOG', '20160211', u'Italy opens tax probe on Google managers-sources ', 'normal')
# ('GOOG', '20160210', u'Exclusive: In boost to self-driving cars  U.S. tells Google computers can qualify as drivers ', 'topStory')
# ('GOOG', '20160210', u'Google to scrub web search results more widely to soothe EU objections ', 'normal')
# ('GOOG', '20160210', u'In boost to self-driving cars  U.S. tells Google computers can qualify as drivers ', 'normal')
# ('GOOG', '20160209', u'Google CEO Pichai receives stock grant worth about $199 million ', 'topStory')
# ('GOOG', '20160209', u'UPDATE 1-Google CEO Pichai receives stock grant worth about $199 mln ', 'normal')
# ('GOOG', '20160208', u'UPDATE 2-Tech stocks extend losses  valuations dented ', 'normal')
# ('GOOG', '20160208', u'Cloud and data analytics stocks extend losses after bloodbath ', 'normal')
# ('GOOG', '20160204', u'Google search chief Singhal to quit  to be replaced by AI head ', 'topStory')
# ('GOOG', '20160203', u"Google's search business chief Amit Singhal to leave ", 'topStory')
# ('GOOG', '20160203', u"Lenovo's Q3 revenue falls 8 pct to $12.9 bln; net profit beats estimates ", 'normal')
# ('GOOG', '20160202', u'Alphabet profit sends shares up; overtakes Apple in value ', 'topStory')
# ('GOOG', '20160202', u'Magic Leap raises $793.5 mln in funding round led by Alibaba ', 'normal')
# ('GOOG', '20160202', u'Alphabet passes Apple to become most valuable traded U.S. company ', 'normal')
# ('GOOG', '20160202', u'PRESS DIGEST- Financial Times - Feb 2 ', 'normal')
# ('GOOG', '20160202', u'UPDATE 3-Alphabet profit sends shares up; overtakes Apple in value ', 'normal')
# ('GOOG', '20160201', u'Alphabet surpasses Apple  now biggest traded US company ', 'topStory')
# ('GOOG', '20160201', u'Alphabet reports 17.8 pct rise in revenue ', 'normal')
# ('GOOG', '20160201', u"Alphabet to give first peek at cost of 'moonshot' bets ", 'normal')
# ('GOOG', '20160129', u'Alphabet changes results format to separate Google  other bets ', 'topStory')
# ('GOOG', '20160129', u"Google says G'day to Australian twang  slang ", 'normal')
# ('GOOG', '20160129', u'UPDATE 2-Alphabet changes results format to separate Google  other bets ', 'normal')
# ('GOOG', '20160128', u'Alphabet to report results in 2 segments: Google  Other Bets ', 'topStory')
# ('GOOG', '20160128', u"YouTube wins German appeal over artists' fees ", 'normal')
# ('GOOG', '20160128', u"CORRECTED-YouTube wins German appeal over artists' fees ", 'normal')
# ('GOOG', '20160127', u"Google files patent for drone 'delivery receptacle' ", 'topStory')
# ('GOOG', '20160127', u'UPDATE 1-UK PM Cameron under pressure over Google tax deal ', 'normal')
# ('GOOG', '20160127', u'U.S. proposes TV set-top box competition to let in new players ', 'normal')
# ('GOOG', '20160127', u'UPDATE 2-U.S. proposes TV set-top box competition to let in new players ', 'normal')
# ('GOOG', '20160127', u'U.S. proposes TV set-top box competition to let in new players ', 'normal')
# ('GOOG', '20160127', u'UK PM Cameron under pressure over Google tax deal ', 'normal')
# ('GOOG', '20160127', u'Google files patent for drone "delivery receptacle" ', 'normal')
# ('GOOG', '20160126', u'Google to face grilling by UK lawmakers over tax deal ', 'topStory')
# ('GOOG', '20160126', u'Ford CEO joins IBM board as auto industry transforms ', 'normal')
# ('GOOG', '20160125', u'Google to face grilling by UK lawmakers over tax deal ', 'normal')
# ('GOOG', '20160123', u'Google to pay $185 million UK back taxes  critics want more ', 'normal')
# ('GOOG', '20160122', u'Google to pay 130 mln pounds in back taxes in UK - FT ', 'topStory')
# ('GOOG', '20160120', u'UPDATE 2-News Corp denies rumors of Twitter bid ', 'normal')
# ('GOOG', '20160112', u'UPDATE 1-Google will add more partners for self-driving cars-exec ', 'normal')
# ('GOOG', '20160112', u"Ford Chairman: 'We are in an experimental stage' ", 'normal')
# GOOG has no news for 20 days, stop this candidate ...
# ('GOOG', '20151222', u'CORRECTED-Top 2015 US stock funds stay defensive heading into 2016 ', 'normal')
# ('GOOG', '20151216', u'Google to make driverless cars an Alphabet company in 2016 - Bbg ', 'topStory')
# ('GOOG', '20151216', u'UPDATE 1-Google to make driverless cars an Alphabet company in 2016-Bbg ', 'normal')
# ('GOOG', '20151216', u'Google to make driverless cars an Alphabet company in 2016 - Bbg ', 'normal')
# ('GOOG', '20151211', u'Alphabet mulls expanding Fiber internet service to LA  Chicago ', 'topStory')
# ('GOOG', '20151211', u'CORRECTED-Alphabet mulls expanding Fiber internet service to LA  Chicago (Dec 8) ', 'normal')
# ('GOOG', '20151210', u'J&J  Alphabet aim for smarter  smaller  cheaper surgical robot ', 'topStory')
# ('GOOG', '20151208', u'Alphabet mulls expanding Fiber internet service to LA  Chicago ', 'topStory')
# ('GOOG', '20151208', u'Alphabet mulls expanding Fiber internet service to LA  Chicago ', 'normal')
# ('GOOG', '20151208', u'Former Google life sciences unit renames itself Verily ', 'normal')
# ('GOOG', '20151207', u'Former Google life sciences unit renames itself Verily ', 'topStory')
# ('GOOG', '20151207', u'Former Google life sciences unit renames itself Verily ', 'normal')
# ('GOOG', '20151203', u'BRIEF-Eolus to build new wind farm to supply Google\x7fs Finnish data center ', 'topStory')
# ('GOOG', '20151201', u"Ryanair to sue Google in Irish court over 'misleading adverts' ", 'topStory')
# ('GOOG', '20151201', u"UPDATE 1-Ryanair to sue Google in Irish court over 'misleading adverts' ", 'normal')
# ('GOOG', '20151201', u'BRIEF-Ryanair says takes legal case against eDreams and Google ', 'normal')
# ('GOOG', '20151130', u"INSIGHT-On China's fringes  cyber spies raise their game ", 'normal')
# ('GOOG', '20151129', u"INSIGHT-On China's fringes  cyber spies raise their game ", 'normal')
# ('GOOG', '20151127', u'Delaware magistrate rules for Google in Collarity patent suit ', 'topStory')
# ('GOOG', '20151120', u'Google aims for China launch of Google Play app store next year: sources ', 'topStory')
# ('GOOG', '20151120', u'UPDATE 2-Google aims for China launch of Google Play app store next year-sources ', 'normal')
# ('GOOG', '20151120', u'US STOCKS-Wall Street on track for best week in over a month ', 'normal')
# ('GOOG', '20151120', u'US STOCKS-S&P set for best week in a year; consumer stocks rise ', 'normal')
# ('GOOG', '20151119', u'Google names VMware co-founder Diane Greene to lead cloud push ', 'topStory')
# ('GOOG', '20151119', u'UPDATE 2-Google names VMware co-founder Diane Greene to lead cloud push ', 'normal')
# ('GOOG', '20151119', u'Google appoints VMware co-founder Greene to run cloud business ', 'normal')
# ('GOOG', '20151117', u"Google to contest Russia's antitrust ruling on Android ", 'topStory')
# ('GOOG', '20151117', u'Ericsson sees video driving tenfold rise in mobile data by 2021 ', 'normal')
# ('GOOG', '20151117', u'UPDATE 1-Ericsson sees video driving tenfold rise in mobile data by 2021 ', 'normal')
# ('GOOG', '20151117', u"Google to contest Russia's antitrust ruling on Android ", 'normal')
# ('GOOG', '20151117', u"UPDATE 1-Google to contest Russia's antitrust ruling on Android ", 'normal')
# ('GOOG', '20151117', u'Google to contest Russia antitrust ruling on Android ', 'normal')
# ('GOOG', '20151113', u"Russia's Yandex says complained to EU over Google's Android ", 'topStory')
# ('GOOG', '20151113', u"UPDATE 1-Russia's Yandex says complained to EU over Google's Android ", 'normal')
# ('GOOG', '20151110', u'Google defeats most claims in browser tracking lawsuit ', 'topStory')
# ('GOOG', '20151110', u'Google defeats most claims in browser tracking lawsuit ', 'normal')
# ('GOOG', '20151110', u'Google defeats most claims in browser tracking lawsuit ', 'normal')
# ('GOOG', '20151109', u'Google gets more time to comply with Russian anti-monopoly ruling ', 'topStory')
# ('GOOG', '20151109', u'Google gets more time to comply with Russian anti-monopoly ruling ', 'normal')
# ('GOOG', '20151104', u"EU's Vestager says all options open in Google case ", 'topStory')
# ('GOOG', '20151104', u"EU's Vestager says all options open in Google case ", 'normal')
# ('GOOG', '20151104', u"UPDATE 1-EU's Vestager says all options open in Google case ", 'normal')
# ('GOOG', '20151104', u'Lufthansa signs Google Flights deal to boost website bookings ', 'normal')
# ('GOOG', '20151103', u'Flipkart hires Google executive to head consumer experience ', 'topStory')
# ('GOOG', '20151103', u'Flipkart hires Google executive to head consumer experience ', 'normal')
# ('GOOG', '20151103', u'Google aims to begin drone package deliveries in 2017 ', 'normal')
# ('GOOG', '20151103', u'Google aims to begin drone package deliveries in 2017 ', 'normal')
# ('GOOG', '20151103', u'UPDATE 2-Google aims to begin drone package deliveries in 2017 ', 'normal')
# ('GOOG', '20151102', u'UPDATE 1-Google aims to begin drone package deliveries in 2017 ', 'topStory')
# ('GOOG', '20151031', u'Google sued by express delivery driver seeking wages ', 'topStory')
# ('GOOG', '20151031', u'Google sued by express delivery driver seeking wages ', 'normal')
# ...
# ('QCOM', '20160815', u'BRIEF-Soros fund management cuts stake in Amazon  dissolves Qualcomm  Nike ', 'topStory')
# ('QCOM', '20160803', u'BRIEF-Qualcomm powers next generation Samsung Galaxy Note7 ', 'topStory')
# ('QCOM', '20160728', u'BRIEF-Precise Biometrics signs licensing deal with Qualcomm ', 'topStory')
# ('QCOM', '20160727', u'BRIEF-Qualcomm  Lear sign commercial wireless electric vehicle charging license agreement ', 'topStory')
# ('QCOM', '20160727', u'Qualcomm to pay $19.5 mln to settle gender discrimination class action ', 'normal')
# ('QCOM', '20160720', u'Strong demand from China buoys Qualcomm forecast ', 'topStory')
# ('QCOM', '20160720', u'UPDATE 2-Strong demand from China buoys Qualcomm forecast ', 'normal')
# ('QCOM', '20160720', u'Qualcomm revenue rises 3.6 percent ', 'normal')
# ('QCOM', '20160712', u'BRIEF-Qualcomm sets qtrly cash dividend of $0.53 per share ', 'topStory')
# ('QCOM', '20160704', u'Monsanto  Microsoft to invest in agricultural technology in Brazil ', 'normal')
# ('QCOM', '20160630', u'BRIEF-Qualcomm files patent infringement complaints against Meizu ', 'topStory')
# ('QCOM', '20160630', u'Qualcomm files 17 new complaints in China courts against smartphone maker Meizu ', 'normal')
# ('QCOM', '20160630', u'Qualcomm files 17 new complaints in China courts against smartphone maker Meizu ', 'normal')
# ('QCOM', '20160624', u'Qualcomm files complaint in China court against smartphone maker Meizu ', 'topStory')
# ('QCOM', '20160617', u'BRIEF-TDK expected to book 130 bln yen profit from spinning off assets to wireless communications partnership with Qualcomm - Nikkei ', 'topStory')
# ('QCOM', '20160610', u'Intel gets mobile chip contract from Apple - Bbg ', 'topStory')
# ('QCOM', '20160610', u'UPDATE 1-Intel gets mobile chip contract from Apple - Bbg ', 'normal')
# ('QCOM', '20160610', u'Intel gets mobile chip contract from Apple - Bloomberg ', 'normal')
# QCOM has no news for 20 days, stop this candidate ...
# QCOM has no news for 40 days, stop this candidate ...
# ('QCOM', '20160420', u'Qualcomm profit forecast misses estimates as chip shipments drop ', 'topStory')
# ('QCOM', '20160420', u'UPDATE 2-Qualcomm profit forecast misses estimates as chip shipments drop ', 'normal')
# ('QCOM', '20160420', u'BRIEF-Qualcomm reports Q2 non-GAAP earnings of $1.04 per share ', 'normal')
# ('QCOM', '20160420', u'BRIEF-Qualcomm signs 3G/4G Chinese patent license agreement with Hisense ', 'normal')
# ('QCOM', '20160420', u'Qualcomm revenue falls 19.5 pct ', 'normal')
# ('QCOM', '20160418', u'BRIEF-Qualcomm signs 3G/4G Chinese patent license agreement with Yulong ', 'topStory')
# ('QCOM', '20160408', u'BRIEF-Qualcomm says quarterly cash dividend of $0.53 per share ', 'topStory')
# ('QCOM', '20160401', u'BRIEF-Qualcomm  Ricardo sign license agreement ', 'topStory')
# ('QCOM', '20160317', u'BRIEF-Qualcomm appoints mary gendron as senior vice president and chief information officer ', 'topStory')
# ('QCOM', '20160314', u'BRIEF-Goertek  Qualcomm sign agreements on chips and software cooperation ', 'topStory')
# ('QCOM', '20160301', u'U.S. fines Qualcomm for hiring relatives of China officials: SEC ', 'topStory')
# ('QCOM', '20160301', u'U.S. fines Qualcomm for hiring relatives of China officials -SEC ', 'normal')
# ('QCOM', '20160301', u'UPDATE 2-U.S. fines Qualcomm for hiring relatives of China officials -SEC ', 'normal')
# ('QCOM', '20160301', u'BRIEF-Qualcomm enters into settlement with U.S. SEC ', 'normal')
# ('QCOM', '20160301', u'U.S. fines Qualcomm for hiring relatives of China officials -SEC ', 'normal')
# QCOM has no news for 20 days, stop this candidate ...
# ('QCOM', '20160202', u'Magic Leap raises $793.5 mln in funding round led by Alibaba ', 'normal')
# ('QCOM', '20160127', u'Qualcomm forecasts weak profit as demand slows for mobile chips ', 'topStory')
# ('QCOM', '20160127', u'UPDATE 2-Qualcomm forecasts weak profit as demand slows for mobile chips ', 'normal')
# ('QCOM', '20160127', u"Qualcomm's quarterly revenue falls 18.7 pct ", 'normal')
# ('QCOM', '20160120', u'GSK said to be in talks with Qualcomm to form JV: Bloomberg ', 'topStory')
# ('QCOM', '20160117', u'Qualcomm unveils $280 million joint venture with Chinese province ', 'topStory')
# ('QCOM', '20160114', u'Samsung Electronics to produce new Qualcomm chips in blow to TSMC ', 'topStory')
# ('QCOM', '20160114', u'UPDATE 2-Samsung Elec to produce new Qualcomm chips in blow to TSMC ', 'normal')
# QCOM has no news for 20 days, stop this candidate ...
# ('QCOM', '20151215', u'Qualcomm decides against breakup  says current structure best ', 'topStory')
# ('QCOM', '20151215', u'CORRECTED-UPDATE 3-Qualcomm decides against breakup  says current structure best ', 'normal')
# ('QCOM', '20151215', u'Qualcomm says to maintain current corporate structure ', 'normal')
# ('QCOM', '20151208', u'EU antitrust regulators accuse Qualcomm of hindering rivals ', 'topStory')
# ('QCOM', '20151202', u'Qualcomm to license patents to Chinese mobile phone maker Xiaomi ', 'topStory')
# ('QCOM', '20151202', u'UPDATE 1-Qualcomm to license patents to Chinese mobile phone maker Xiaomi ', 'normal')
# ('QCOM', '20151202', u'Qualcomm to license patents to Chinese mobile phone maker Xiaomi ', 'normal')
# QCOM has no news for 20 days, stop this candidate ...
# ('QCOM', '20151105', u"China woes hurt chipmaker Qualcomm's profit forecast ", 'topStory')
# ('QCOM', '20151104', u"China woes hurt chipmaker Qualcomm's profit forecast ", 'topStory')
# ('QCOM', '20151104', u"UPDATE 2-China woes hurt chipmaker Qualcomm's profit forecast ", 'normal')
# ('QCOM', '20151104', u"Chipmaker Qualcomm's quarterly profit plunges 44 pct ", 'normal')
# ('QCOM', '20151020', u"BRIEF-Wuhan Tianyu Information  Qualcomm's units in cooperation agreement ", 'topStory')
# QCOM has no news for 20 days, stop this candidate ...
# QCOM has no news for 40 days, stop this candidate ...
# ('QCOM', '20150903', u'Qualcomm president says splitting company may not create value ', 'topStory')
# ('QCOM', '20150826', u'Ex-Merrill Lynch broker spared prison in Qualcomm insider trading case ', 'topStory')
# ('QCOM', '20150826', u'Qualcomm sells UK spectrum rights to Vodafone and CK Hutchison -Bloomberg ', 'normal')
# ('QCOM', '20150812', u"China's Tsinghua to invest $4.7 bln in mobile chips-China Daily ", 'topStory')
# ('QCOM', '20150731', u'Qualcomm wins appeal in $173 mln ParkerVision case ', 'topStory')
# ('QCOM', '20150731', u'Qualcomm wins appeal in $173 million ParkerVision case ', 'normal')
# ('QCOM', '20150731', u'UPDATE 1-Qualcomm wins appeal in $173 mln ParkerVision case ', 'normal')
# ('QCOM', '20150731', u'Qualcomm wins appeal in $173 mln ParkerVision case ', 'normal')
# ('QCOM', '20150724', u"BRIEF-CSR says China clears Qualcomm's acquisition of CSR ", 'topStory')
# ('QCOM', '20150724', u"Qualcomm's potential break-up could lead to courtship with Intel ", 'normal')
# ('QCOM', '20150723', u"Qualcomm's potential break-up could lead to courtship with Intel ", 'topStory')
# ('QCOM', '20150723', u"Qualcomm's potential break-up could lead to courtship with Intel ", 'normal')
# ('QCOM', '20150722', u'Qualcomm slashes jobs and costs  says may split itself up ', 'topStory')
# ('QCOM', '20150722', u'UPDATE 5-Qualcomm slashes jobs and costs  says may split itself up ', 'normal')
# ('QCOM', '20150722', u'RPT-UPDATE 1-Qualcomm says may split itself  cut jobs ', 'normal')
# ('QCOM', '20150722', u'Qualcomm says may split itself ', 'normal')
# ('QCOM', '20150722', u'$5.7 billion wiped off European tech shares after Apple outlook disappoints ', 'normal')
# ('QCOM', '20150721', u'Qualcomm may consider breakup: WSJ ', 'topStory')
# ('QCOM', '20150721', u'Qualcomm may consider breakup - WSJ ', 'normal')
# ('QCOM', '20150720', u'Qualcomm preparing to lay off several thousand employees: tech website ', 'topStory')
# ('QCOM', '20150720', u'UPDATE 1-Qualcomm preparing to lay off several thousand employees - tech website ', 'normal')
# ('QCOM', '20150720', u'CORRECTED-Qualcomm preparing to layoff as many as several thousand employees -tech website ', 'normal')
# ('QCOM', '20150716', u'Qualcomm faces EU antitrust probes over tactics to block rivals ', 'topStory')
# ('QCOM', '20150716', u'UPDATE 2-Qualcomm faces EU antitrust probes over tactics to block rivals ', 'normal')
# ('QCOM', '20150716', u'BRIEF-Wuhan Tianyu Information Industry plans cooperation with Qualcomm ', 'normal')
# ('QCOM', '20150716', u'EU opens twin Qualcomm antitrust investigations ', 'normal')
# ('QCOM', '20150716', u'RPT-EU opens two antritust investigations against Qualcomm ', 'normal')
# ('QCOM', '20150716', u'EU opens two antritust investigations against Qualcomm ', 'normal')
# ('QCOM', '20150713', u'Moelis & Co adds new semiconductor banker -memo ', 'normal')
# ('QCOM', '20150707', u'China economic uncertainty a potential risk for U.S. chipmakers ', 'topStory')
# ('QCOM', '20150630', u'Qualcomm has no plans to spin off chip business at present: chairman ', 'topStory')
# ('QCOM', '20150626', u'Ex-Qualcomm exec gets one-and-a-half years in prison for insider trades ', 'topStory')
# ('QCOM', '20150626', u'Ex-Qualcomm exec gets 1-1/2 years in prison for insider trades ', 'normal')
# ('QCOM', '20150626', u'Ex-Qualcomm exec gets 1-1/2 years in prison for insider trades ', 'normal')
# ('QCOM', '20150611', u'Qualcomm names old-hand as new China chairman; former head joins Xiaomi ', 'topStory')
# ('QCOM', '20150611', u'Qualcomm names old-hand as new China chairman; former head joins Xiaomi ', 'normal')
# ('QCOM', '20150608', u'Qualcomm puts UK spectrum up for sale ', 'topStory')
# ('QCOM', '20150528', u'Avago  Broadcom deal could put pressure on Qualcomm ', 'topStory')
# ('QCOM', '20150524', u'Daimler and Qualcomm to develop in-car tech  wireless charging ', 'topStory')
# ('QCOM', '20150523', u'Daimler and Qualcomm to develop in-car tech  wireless charging ', 'topStory')
# ('QCOM', '20150523', u'Daimler and Qualcomm to develop in-car tech  wireless charging ', 'normal')
# ('QCOM', '20150508', u'EU antitrust regulators query Qualcomm rivals on its business practices ', 'topStory')
# ('QCOM', '20150508', u'EU antitrust regulators query Qualcomm rivals on its business practices ', 'normal')
# ('QCOM', '20150507', u'EU antitrust regulators not probing Qualcomm licensing deals -EU source ', 'topStory')
# ('QCOM', '20150507', u'UPDATE 1-EU antitrust regulators not probing Qualcomm licensing deals -EU source ', 'normal')
# ('QCOM', '20150507', u'EU antitrust regulators not probing Qualcomm licensing deals - EU source ', 'normal')
# ('QCOM', '20150506', u'South Korea says to cooperate with Europe  U.S. on Qualcomm probe ', 'topStory')
# ('QCOM', '20150506', u'S.Korea says to cooperate with Europe  U.S. on Qualcomm probe ', 'normal')
# ('QCOM', '20150504', u'GE ties up with Qualcomm  Apple in new lighting business bet ', 'topStory')
# ('QCOM', '20150504', u'GE ties up with Qualcomm  Apple in new lighting business bet ', 'normal')
# ('QCOM', '20150428', u'UPDATE 1-S.Korea investigating Oracle over software bundling ', 'normal')
# ('QCOM', '20150422', u'Qualcomm forecast misses as customer loss hurts mobile chip sales ', 'topStory')
# ('QCOM', '20150422', u'UPDATE 2-Qualcomm forecast misses as customer loss hurts mobile chip sales ', 'normal')
# ('QCOM', '20150422', u"Chipmaker Qualcomm's quarterly profit plunges 46 pct ", 'normal')
# ('QCOM', '20150421', u'Qualcomm to tap Samsung Elec to make new mobile processors: report ', 'topStory')
# ('QCOM', '20150421', u'Qualcomm to tap Samsung Elec to make new mobile processors - report ', 'normal')
# ('QCOM', '20150417', u'Hedge fund pressure unlikely to block Qualcomm bond ', 'topStory')
# ('QCOM', '20150417', u'What to Watch in the Week Ahead and on Monday  April 20 ', 'normal')
# ('QCOM', '20150416', u'UPDATE 2-TSMC sees Q2 sales dip after key client loses business ', 'topStory')
# ('QCOM', '20150416', u"CORRECTED-UPDATE 1-Taiwan's TSMC books 65 pct rise in Q1 net profit  beats estimates ", 'normal')
# ('QCOM', '20150414', u"UPDATE 1-BlackRock's Fink tells S&P 500 firms to think long-term ", 'normal')
# ('QCOM', '20150413', u'Wall St. declines as worries about earnings deepen ', 'topStory')
# ('QCOM', '20150413', u'Deals of the day- Mergers and acquisitions ', 'normal')
# ('QCOM', '20150413', u'Jana Partners pressing Qualcomm to spin off chip business ', 'normal')
# ('QCOM', '20150413', u'UPDATE 4-Jana Partners pressing Qualcomm to spin off chip business ', 'normal')
# ('QCOM', '20150413', u'US STOCKS-Nasdaq near all-time high on lift from tech ', 'normal')
# ('QCOM', '20150413', u'US STOCKS-Wall St flat with earnings eyed; Apple  Qualcomm lift Nasdaq ', 'normal')
# ('QCOM', '20150413', u"Investor Jana's Rosenstein wants to 'pull levers' to boost Qualcomm ", 'normal')
# ('QCOM', '20150413', u"Investor Jana's Rosenstein wants to 'pull levers' to boost Qualcomm ", 'normal')
# ('QCOM', '20150413', u'REFILE-US STOCKS-Wall St to dip at open after three-day run; earnings eyed ', 'normal')
# ('QCOM', '20150413', u'BRIEF-Jana Partners urges Qualcomm to consider spinning off its chip unit ', 'normal')
# ('QCOM', '20150409', u'UPDATE 2-Samsung expects record Galaxy shipments  S6 edge shortage ', 'topStory')
# ('QCOM', '20150406', u'US STOCKS-Wall Street to open lower in wake of weak jobs data ', 'topStory')
# ('QCOM', '20150403', u'Teardown of new Samsung Galaxy smartphone suggests deeper loss for Qualcomm ', 'topStory')
# ('QCOM', '20150403', u'Teardown of new Samsung Galaxy smartphone suggests deeper loss for Qualcomm ', 'normal')
# QCOM has no news for 20 days, stop this candidate ...
# ('QCOM', '20150310', u'US STOCKS-Wall St slumps on Greece concerns ', 'topStory')
# ('QCOM', '20150310', u'US STOCKS-Futures imply lower open on Greece concerns  China data ', 'normal')
# ('QCOM', '20150310', u'US STOCKS-Futures weaken on Greece concerns  China data ', 'normal')
# ('QCOM', '20150310', u'US STOCKS-Futures tumble on Greece concerns  China data ', 'normal')
# ('QCOM', '20150309', u'Qualcomm to buy back up to $15 bln of shares  raise dividend ', 'topStory')
# ('QCOM', '20150309', u'UPDATE 1-Qualcomm to buy back up to $15 bln of shares  raise dividend ', 'normal')
# ('QCOM', '20150309', u'Qualcomm to buy back up to $15 bln of shares  raise dividend ', 'normal')
# ('QCOM', '20150305', u'BRIEF-CSR says core business continues to perform well ', 'topStory')
# ('QCOM', '20150302', u'Honeywell  OneWeb partner to offer satellite internet to aircraft ', 'topStory')
# ('QCOM', '20150302', u'DIARY-U.S. MEETINGS/WEEK AHEAD ', 'normal')
# ('QCOM', '20150302', u'Qualcomm seeks to pave road to marriage of cars and smartphones ', 'normal')
# ('QCOM', '20150302', u'Qualcomm seeks to pave road to marriage of cars and smartphones ', 'normal')
# ('QCOM', '20150220', u'Ex-Qualcomm executive pleads guilty to insider trading ', 'topStory')
# ('QCOM', '20150220', u'Ex-Qualcomm executive pleads guilty to insider trading ', 'normal')
# ('QCOM', '20150220', u'Ex-Qualcomm executive pleads guilty to insider trading ', 'normal')
#  -  -  -
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-704fa188da51> in <module>()
#     123
#     124 if __name__ == "__main__":
# --> 125     main()
#
# <ipython-input-1-704fa188da51> in main()
#     120
#     121 def main():
# --> 122     news_Reuters()
#     123
#     124 if __name__ == "__main__":
#
# <ipython-input-1-704fa188da51> in __init__(self)
#      30             if ticker in filterList: continue
#      31             print("%s - %s - %s - %s" % (ticker, name, exchange, MarketCap))
# ---> 32             self.contents(ticker, name, line, dateList, exchange)
#      33
#      34     def contents(self, ticker, name, line, dateList, exchange):
#
# <ipython-input-1-704fa188da51> in contents(self, ticker, name, line, dateList, exchange)
#      36         suffix = {'AMEX': '.A', 'NASDAQ': '.O', 'NYSE': '.N'}
#      37         # e.g. http://www.reuters.com/finance/stocks/company-news/BIDU.O?date=09262017
# ---> 38         url = "http://www.reuters.com/finance/stocks/companyNews/" + ticker + suffix[exchange]
#      39         has_Content = 0
#      40         repeat_times = 4
#
# KeyError: ''
